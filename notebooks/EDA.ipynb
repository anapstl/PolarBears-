# %% [markdown]
# # EDA

# %%
# !pip install ipyleaflet
# !pip install cartopy
# !pip install xarray netCDF4 geopy tqdm skyfield requests pyproj
# !pip install plotly.express
# Out:
# Collecting plotly.express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\ana\appdata\local\programs\python\python311\lib\site-packages (from plotly.express) (2.2.3)
# Collecting plotly>=4.1.0 (from plotly.express)
#   Downloading plotly-6.2.0-py3-none-any.whl (9.6 MB)
#                                               0.0/9.6 MB ? eta -:--:--
#                                               0.0/9.6 MB 660.6 kB/s eta 0:00:15
#                                               0.1/9.6 MB 787.7 kB/s eta 0:00:13
#                                               0.2/9.6 MB 1.5 MB/s eta 0:00:07
#      -                                        0.3/9.6 MB 1.8 MB/s eta 0:00:06
#      -                                        0.4/9.6 MB 2.0 MB/s eta 0:00:05
#      --                                       0.6/9.6 MB 2.2 MB/s eta 0:00:05
#      ---                                      0.9/9.6 MB 2.8 MB/s eta 0:00:04
#      ----                                     1.2/9.6 MB 3.2 MB/s eta 0:00:03
#      ------                                   1.5/9.6 MB 3.6 MB/s eta 0:00:03
#      -------                                  1.8/9.6 MB 3.9 MB/s eta 0:00:03
#      --------                                 2.1/9.6 MB 4.1 MB/s eta 0:00:02
#      ---------                                2.3/9.6 MB 4.3 MB/s eta 0:00:02
#      -----------                              2.7/9.6 MB 4.4 MB/s eta 0:00:02
#      ------------                             2.9/9.6 MB 4.7 MB/s eta 0:00:02
#      -------------                            3.3/9.6 MB 4.8 MB/s eta 0:00:02
#      ---------------                          3.7/9.6 MB 5.0 MB/s eta 0:00:02
#      ----------------                         4.0/9.6 MB 5.1 MB/s eta 0:00:02
#      -----------------                        4.3/9.6 MB 5.1 MB/s eta 0:00:02
#      -------------------                      4.6/9.6 MB 5.2 MB/s eta 0:00:01
#      --------------------                     4.9/9.6 MB 5.3 MB/s eta 0:00:01
#      ---------------------                    5.2/9.6 MB 5.3 MB/s eta 0:00:01
#      ----------------------                   5.4/9.6 MB 5.3 MB/s eta 0:00:01
#      -----------------------                  5.8/9.6 MB 5.4 MB/s eta 0:00:01
#      -------------------------                6.1/9.6 MB 5.5 MB/s eta 0:00:01
#      --------------------------               6.3/9.6 MB 5.5 MB/s eta 0:00:01
#      ---------------------------              6.6/9.6 MB 5.6 MB/s eta 0:00:01
#      -----------------------------            7.0/9.6 MB 5.6 MB/s eta 0:00:01
#      ------------------------------           7.3/9.6 MB 5.7 MB/s eta 0:00:01
#      -------------------------------          7.6/9.6 MB 5.7 MB/s eta 0:00:01
#      --------------------------------         7.9/9.6 MB 5.7 MB/s eta 0:00:01
#      ---------------------------------        8.1/9.6 MB 5.8 MB/s eta 0:00:01
#      -----------------------------------      8.6/9.6 MB 5.8 MB/s eta 0:00:01
#      -------------------------------------    8.9/9.6 MB 5.9 MB/s eta 0:00:01
#      --------------------------------------   9.2/9.6 MB 5.9 MB/s eta 0:00:01
#      ---------------------------------------  9.5/9.6 MB 5.9 MB/s eta 0:00:01
#      ---------------------------------------  9.6/9.6 MB 5.9 MB/s eta 0:00:01
#      ---------------------------------------- 9.6/9.6 MB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\ana\appdata\local\programs\python\python311\lib\site-packages (from plotly.express) (0.14.4)
# Requirement already satisfied: scipy>=0.18 in c:\users\ana\appdata\local\programs\python\python311\lib\site-packages (from plotly.express) (1.15.2)
# Requirement already satisfied: patsy>=0.5 in c:\users\ana\appdata\local\programs\python\python311\lib\site-packages (from plotly.express) (1.0.1)
# Requirement already satisfied: numpy>=1.11 in c:\users\ana\appdata\local\programs\python\python311\lib\site-packages (from plotly.express) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ana\appdata\roaming\python\python311\site-packages (from pandas>=0.20.0->plotly.express) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ana\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ana\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\ana\appdata\local\programs\python\python311\lib\site-packages (from plotly>=4.1.0->plotly.express) (1.42.1)
# Requirement already satisfied: packaging in c:\users\ana\appdata\roaming\python\python311\site-packages (from plotly>=4.1.0->plotly.express) (24.2)
# Requirement already satisfied: six>=1.5 in c:\users\ana\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->plotly.express) (1.17.0)
# Installing collected packages: plotly, plotly.express
# Successfully installed plotly-6.2.0 plotly.express-0.4.1
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import folium
import matplotlib.colors as colors
import matplotlib.cm as cm
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
from sklearn.model_selection import cross_val_score

warnings.filterwarnings("ignore")

# %% [markdown]
# ### **DF Original**

# %%
df_orig = pd.read_csv('../data/raw/polarBear_CTCRWlocations_chukchiBeaufort_1985-2017.csv')
df_orig.head()
# Out:
#    UniqueAnimalID       timestamp   mu_lat    mu_lon  se_mu_x  se_mu_y
# 0               1   7/1/1986 0:00  69.7687 -141.3759    14589    14589
# 1               1   7/1/1986 6:00  69.7703 -141.3863    12248    12248
# 2               1  7/1/1986 12:00  69.7718 -141.3942     9375     9375
# 3               1  7/1/1986 18:00  69.7730 -141.3960     5835     5835
# 4               1   7/2/1986 0:00  69.7738 -141.3834     2517     2517

# %%
df_orig.shape
# Out:
# (338413, 6)

# %%
df_orig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338413 entries, 0 to 338412
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   UniqueAnimalID  338413 non-null  int64
#  1   timestamp       338413 non-null  object
#  2   mu_lat          338413 non-null  float64
#  3   mu_lon          338413 non-null  float64
#  4   se_mu_x         338413 non-null  int64
#  5   se_mu_y         338413 non-null  int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 15.5+ MB

# %% [markdown]
# # TODO clear

# %%
df = df_orig.copy()

# df['timestamp'] = pd.to_datetime(df['timestamp'])
# df = df[(df['timestamp'].dt.year == 2013)]
# df.head()

# def asignar_season(date):
#     month = date.month
#     if month in [6, 7, 8, 9]:
#         return "verano"
#     elif month in [11, 12, 1, 2, 3, 4]:
#         return "invierno"
#     else:
#         return "transicion"

# df['month'] = df['timestamp'].dt.month
# df['season'] = df['timestamp'].apply(asignar_season)
df['year'] = df['timestamp'].year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10596\2350313607.py in ?()
#      14 #         return "transicion"
#      15
#      16 # df['month'] = df['timestamp'].dt.month
#      17 # df['season'] = df['timestamp'].apply(asignar_season)
# ---> 18 df['year'] = df['timestamp'].year
#
# c:\Users\Ana\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'year'

# %%
df.head()
# Out:
#         UniqueAnimalID           timestamp   mu_lat    mu_lon  se_mu_x  \
# 196864             311 2013-07-01 00:00:00  70.5648 -135.9348       31
# 196865             311 2013-07-01 06:00:00  70.5822 -136.0121       30
# 196866             311 2013-07-01 12:00:00  70.4862 -136.0627       30
# 196867             311 2013-07-01 18:00:00  70.4714 -136.2293       30
# 196868             311 2013-07-02 00:00:00  70.4720 -136.4244       30
#
#         se_mu_y  month  season  year
# 196864       31      7  verano  2013
# 196865       30      7  verano  2013
# 196866       30      7  verano  2013
# 196867       30      7  verano  2013
# 196868       30      7  verano  2013

# %% [markdown]
# ### **DF PROCESSED**

# %%
df = pd.read_csv('../data/processed/polar_bear_processed_final.csv')
df.head()
# Out:
#    UniqueAnimalID            timestamp   mu_lat    mu_lon  se_mu_x  se_mu_y  \
# 0             120  2008-08-30 06:00:00  70.5710 -151.8802       30       30
# 1             120  2008-08-30 12:00:00  70.5710 -151.8801       30       30
# 2             120  2008-08-30 18:00:00  70.5706 -151.8790       30       30
# 3             120  2008-08-31 00:00:00  70.5714 -151.8821       30       30
# 4             120  2008-08-31 06:00:00  70.5714 -151.8822       30       30
#
#      adj_lat     adj_lon    date_str   lat2  ...  cloud_cover   prev_lat  \
# 0  68.827253 -154.186473  2008-08-30  68.83  ...          NaN        NaN
# 1  70.907069 -148.223496  2008-08-30  70.91  ...          NaN  68.827253
# 2  73.027631 -146.546143  2008-08-30  73.03  ...          NaN  70.907069
# 3  71.741506 -159.600333  2008-08-31  71.74  ...          NaN  73.027631
# 4  71.983567 -152.208099  2008-08-31  71.98  ...          NaN  71.741506
#
#      prev_lon  prev_se_x  prev_se_y     bearing  prev_bearing  bearing_change  \
# 0         NaN        NaN        NaN         NaN           NaN        0.000000
# 1 -154.186473       30.0       30.0  193.599098           NaN        0.000000
# 2 -148.223496       30.0       30.0  140.935508    193.599098       52.663590
# 3 -146.546143       30.0       30.0  177.763315    140.935508       36.827807
# 4 -159.600333       30.0       30.0  160.095261    177.763315       17.668054
#
#          date  distance_per_day
# 0  2008-08-30        567.382189
# 1  2008-08-30        567.382189
# 2  2008-08-30        567.382189
# 3  2008-08-31       1416.241258
# 4  2008-08-31       1416.241258
#
# [5 rows x 32 columns]

# %%
df.shape
# Out:
# (122014, 32)

# %%
df.cdr_seaice_conc[df.cdr_seaice_conc > 0]
# Out:
# 29        0.58
# 47        0.75
# 49        2.53
# 69        0.26
# 99        1.00
#           ...
# 121483    1.00
# 121511    2.53
# 121515    1.00
# 121538    1.00
# 121951    1.00
# Name: cdr_seaice_conc, Length: 17880, dtype: float64

# %% [markdown]
# ## **Hoja de ruta**
#
# ---
#
# ### 1. **Info dataset**
#
# * Tipos de datos (`dtypes`) y si coinciden con lo esperado.
# * Presencia de valores nulos (`Non-Null Count`) en cada columna.
# * Distribución temporal (`timestamp`, `date`, `date_str`).
# * Unicidad de IDs (`UniqueAnimalID`).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122014 entries, 0 to 122013
# Data columns (total 32 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   UniqueAnimalID     122014 non-null  int64
#  1   timestamp          122014 non-null  object
#  2   mu_lat             122014 non-null  float64
#  3   mu_lon             122014 non-null  float64
#  4   se_mu_x            122014 non-null  int64
#  5   se_mu_y            122014 non-null  int64
#  6   adj_lat            122014 non-null  float64
#  7   adj_lon            122014 non-null  float64
#  8   date_str           122014 non-null  object
#  9   lat2               122014 non-null  float64
#  10  lon2               122014 non-null  float64
#  11  proj_x             122014 non-null  float64
#  12  proj_y             122014 non-null  float64
#  13  distance_km        122014 non-null  float64
#  14  velocity_kmh       122014 non-null  float64
#  15  acceleration_kmh2  122014 non-null  float64
#  16  daylight_hours     122014 non-null  float64
#  17  is_polar_night     122014 non-null  bool
#  18  is_midnight_sun    122014 non-null  bool
#  19  cdr_seaice_conc    31664 non-null   float64
#  20  temp_surface       0 non-null       float64
#  21  wind_speed         0 non-null       float64
#  22  cloud_cover        0 non-null       float64
#  23  prev_lat           121841 non-null  float64
#  24  prev_lon           121841 non-null  float64
#  25  prev_se_x          121841 non-null  float64
#  26  prev_se_y          121841 non-null  float64
#  27  bearing            121841 non-null  float64
#  28  prev_bearing       121668 non-null  float64
#  29  bearing_change     122014 non-null  float64
#  30  date               122014 non-null  object
#  31  distance_per_day   122014 non-null  float64
# dtypes: bool(2), float64(24), int64(3), object(3)
# memory usage: 28.2+ MB

# %%
df.select_dtypes(include='object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122014 entries, 0 to 122013
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  122014 non-null  object
#  1   date_str   122014 non-null  object
#  2   date       122014 non-null  object
# dtypes: object(3)
# memory usage: 2.8+ MB

# %% [markdown]
# * **Nulos**

# %%
null_summary = df.isnull().sum().to_frame(name='nulos')
null_summary['porcentaje'] = 100 * null_summary['nulos'] / len(df)
null_summary = null_summary[null_summary.porcentaje > 0]
print(null_summary)
# Out:
#                   nulos  porcentaje
# cdr_seaice_conc   90350   74.048880
# temp_surface     122014  100.000000
# wind_speed       122014  100.000000
# cloud_cover      122014  100.000000
# prev_lat            173    0.141787
# prev_lon            173    0.141787
# prev_se_x           173    0.141787
# prev_se_y           173    0.141787
# bearing             173    0.141787
# prev_bearing        346    0.283574

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# mirar con la libreria 'rerddapxtracto '

# %% [markdown]
# ---
#
# ### 3. **Exploración geográfica y temporal**
#
# * Rango de fechas (`timestamp`, `date`).
# * Trayectorias o movimiento por individuo (`UniqueAnimalID`).
# * Cobertura geográfica: distribución de puntos en lat/lon y por zona (`lat2`, `lon2`, `proj_x`, `proj_y`).

# %% [markdown]
# * **Unicidad de IDs**

# %%
df.UniqueAnimalID.nunique()
# Out:
# 173

# %%
df.UniqueAnimalID.unique()
# Out:
# array([120, 124, 211, 215, 260, 261, 263, 265, 276, 280, 286, 293, 297,
#        300, 302, 304, 306, 310, 311, 313, 316, 320, 324, 326, 328, 339,
#        344, 349, 351, 354, 355, 356, 358, 360, 361, 362, 363, 364, 365,
#        367, 369, 370, 371, 373, 374, 375, 377, 378, 379, 380, 381, 382,
#        383, 384, 385, 386, 388, 389, 394, 395, 396, 397, 398, 399, 401,
#        402, 403, 404, 405, 406, 407, 409, 410, 411, 412, 413, 414, 415,
#        416, 418, 419, 422, 423, 425, 426, 427, 428, 430, 431, 432, 433,
#        435, 436, 437, 438, 440, 441, 442, 443, 444, 447, 450, 451, 452,
#        453, 454, 455, 456, 457, 458, 459, 463, 465, 466, 467, 468, 469,
#        470, 471, 472, 473, 474, 475, 477, 478, 479, 480, 482, 483, 484,
#        485, 486, 488, 489, 491, 492, 493, 495, 500, 501, 503, 505, 507,
#        508, 510, 511, 512, 514, 515, 516, 517, 518, 519, 520, 521, 522,
#        524, 525, 526, 527, 528, 529, 530, 531, 532, 533, 534, 535, 536,
#        537, 539, 540, 541])

# %%
# df[df['UniqueAnimalID'] == 418].plot(x='mu_lon', y='mu_lat')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filtrar por el ID deseado
df_418 = df[df['UniqueAnimalID'] == 418]

# Crear scatterplot con seaborn
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_418, x='mu_lon', y='mu_lat', hue='timestamp', palette='viridis', legend=False)

# Opcional: conectamos los puntos en orden temporal
sns.lineplot(data=df_418, x='mu_lon', y='mu_lat', color='gray', alpha=0.3)

plt.title('Trayectoria del oso polar ID 418')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.gca().invert_xaxis()  # En mapas del Ártico, a veces conviene invertir eje X
plt.grid(True)
plt.show()

# %% [markdown]
# TODO: colorear por fecha, velocidad u otra variable como temperatura o hielo marino (`cdr_seaice_conc`)

# %% [markdown]
# * **Distribución temporal**: _timestamp, date, date_str_

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')

print("Rango de fechas:", df['timestamp'].min(), "→", df['timestamp'].max())
df['timestamp'].dt.year.value_counts().sort_index()
# Out:
# Rango de fechas: 2007-07-01 00:00:00 → 2017-11-30 18:00:00
# timestamp
# 2007     9748
# 2008    18827
# 2009    23881
# 2010    13987
# 2011    15166
# 2012     4423
# 2013     8790
# 2014     7344
# 2015    10045
# 2016     4482
# 2017     5321
# Name: count, dtype: int64

# %%
# Registros por mes/año
# df['timestamp'].dt.to_period('M').value_counts().sort_index().plot()

# %%
df['month'] = df['timestamp'].dt.to_period('M').astype(str)
montly_counts = df.month.value_counts().sort_index()

monthly_df = montly_counts.reset_index()
# monthly_df

# %%
monthly_df.columns =['month', 'count']

plt.figure(figsize=(12, 5))
sns.lineplot(data=monthly_df, x='month', y='count')
plt.xticks(rotation=45)
plt.title('Número de registros por mes')
plt.tight_layout()
plt.show();

# %% [markdown]
# ---
#
# ### 2. **Análisis de calidad de datos**
#
# * Buscar columnas con muchos nulos (como `temp_surface`, `wind_speed`, `cloud_cover`) y decidir si se imputan, se eliminan o se busca su fuente.
# * Verificar duplicados.
# * Validar rangos de coordenadas (`mu_lat`, `mu_lon`, `adj_lat`, `adj_lon`) y que no existan errores geográficos.

# %%
# TODO

# %% [markdown]
# ---
#
# ### 4. **Exploración por individuo**
#
# * Número de registros por `UniqueAnimalID`.
# * Longitud de trayectorias (en tiempo y espacio).
# * Cambios de dirección (`bearing_change`) y sus patrones.

# %%
df.groupby('UniqueAnimalID').size()

# %%
df.head()
# Out:
#         UniqueAnimalID           timestamp   mu_lat    mu_lon  se_mu_x  \
# 134907             215 2009-08-19 06:00:00  70.8765 -152.5880      995
# 134908             215 2009-08-19 12:00:00  70.8765 -152.5840     1080
# 134909             215 2009-08-19 18:00:00  70.8765 -152.5775      493
# 134910             215 2009-08-20 00:00:00  70.8750 -152.5720      273
# 134911             215 2009-08-20 06:00:00  70.8693 -152.5407      974
#
#         se_mu_y  month  season
# 134907      995      8  verano
# 134908     1080      8  verano
# 134909      493      8  verano
# 134910      273      8  verano
# 134911      974      8  verano

# %% [markdown]
# #### Heatmap por oso y estación

# %%
df[df.UniqueAnimalID == 311]
# Out:
# Empty DataFrame
# Columns: [UniqueAnimalID, timestamp, mu_lat, mu_lon, se_mu_x, se_mu_y, month, season]
# Index: []

# %%
import plotly.express as px

# df_filtrado = df[(df['id_oso'].isin(lista_osos)) & (df['año'] == año_seleccionado)]
df_filtrado = df[(df['UniqueAnimalID'] == 311)]

fig = px.scatter_mapbox(
    df_filtrado,
    lat="mu_lat",
    lon="mu_lon",
    color="season",  # Esto codifica por estación
    # animation_frame="año",  # Si lo deseas animado por año
    mapbox_style="carto-positron",
    zoom=3,
    height=600
)
fig.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8790 entries, 196864 to 330548
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   UniqueAnimalID  8790 non-null   int64
#  1   timestamp       8790 non-null   datetime64[ns]
#  2   mu_lat          8790 non-null   float64
#  3   mu_lon          8790 non-null   float64
#  4   se_mu_x         8790 non-null   int64
#  5   se_mu_y         8790 non-null   int64
#  6   month           8790 non-null   int32
#  7   season          8790 non-null   object
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(3), object(1)
# memory usage: 583.7+ KB

# %%
from ipyleaflet import Map, CircleMarker, LayerGroup, WidgetControl
import matplotlib.cm as cm
import matplotlib.colors as mcolors
import ipywidgets as widgets
import pandas as pd
import numpy as np

# Supongamos que tu df tiene: 'latitud', 'longitud', 'season', 'año'

# 👉 Mapa base centrado en el Ártico
m = Map(center=(72, -150), zoom=3)

# 👉 Asignamos colores a las estaciones
estaciones = ['invierno', 'transición', 'verano']
colormap = cm.get_cmap('magma', len(estaciones))
norm = mcolors.Normalize(vmin=0, vmax=len(estaciones)-1)
colores = {est: mcolors.to_hex(colormap(norm(i))) for i, est in enumerate(estaciones)}

# 👉 Widget para elegir año
años_disponibles = sorted(df['año'].unique())
slider = widgets.SelectionSlider(
    options=años_disponibles,
    value=años_disponibles[0],
    description='Año:',
    continuous_update=False
)

# 👉 Capa dinámica de círculos
marcadores = LayerGroup()
m.add_layer(marcadores)

def actualizar_mapa(cambio):
    año = slider.value
    marcadores.clear_layers()
    df_filtrado = df[df['año'] == año]

    for _, row in df_filtrado.iterrows():
        color = colores.get(row['season'], '#888888')
        marker = CircleMarker(
            location=(row['latitud'], row['longitud']),
            radius=3,
            color=color,
            fill_opacity=0.6
        )
        marcadores.add_layer(marker)

# 👉 Conecta el slider al mapa
slider.observe(actualizar_mapa, names='value')

# 👉 Primera visualización
actualizar_mapa(None)

# 👉 Muestra todo
control = WidgetControl(widget=slider, position='topright')
m.add_control(control)
display(m)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Ana\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'año'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 20
#      17 colores = {est: mcolors.to_hex(colormap(norm(i))) for i, est in enumerate(estaciones)}
#      19 # 👉 Widget para elegir año
# ---> 20 años_disponibles = sorted(df['año'].unique())
#      21 slider = widgets.SelectionSlider(
#      22     options=años_disponibles,
#      23     value=años_disponibles[0],
#      24     description='Año:',
#      25     continuous_update=False
#      26 )
#      28 # 👉 Capa dinámica de círculos
#
# File c:\Users\Ana\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Ana\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'año'

# %% [markdown]
# ---
#
# ### 5. **Distribución de variables clave**
#
# * Histogramas / boxplots de:
#
#   * `distance_km`, `velocity_kmh`, `acceleration_kmh2`
#   * `daylight_hours`, `cdr_seaice_conc`, `distance_per_day`
# * Comparación de distribuciones por época del año, individuo o región.

# %%
import matplotlib.pyplot as plt

# Histograma de velocidad
df['velocity_kmh'].hist(bins=50)

# Boxplot de aceleración
sns.boxplot(data=df, y='acceleration_kmh2');

# %%
variables = [
    'distance_km',
    'velocity_kmh',
    'acceleration_kmh2',
    'daylight_hours',
    'cdr_seaice_conc',
    'distance_per_day'
]

plt.figure(figsize=(18, 12))

for i, var in enumerate(variables):
    plt.subplot(3, 4, 2*i+1)
    sns.histplot(df[var].dropna(), kde=True, bins=30)
    plt.title(f'Histograma de {var}')
    
    plt.subplot(3, 4, 2*i+2)
    sns.boxplot(x=df[var])
    plt.title(f'Boxplot de {var}')

plt.tight_layout()
plt.show()

# %%
df['month'] = pd.to_datetime(df['date']).dt.month

plt.figure(figsize=(15, 10))
sns.boxplot(x='month', y='distance_per_day', data=df, palette='pastel')
plt.title('Distance per day por mes')
plt.xlabel('Mes')
plt.ylabel('Distancia diaria (km)')
plt.show()

# %%
sample_ids = df['UniqueAnimalID'].value_counts().head(6).index.tolist()
plt.figure(figsize=(15, 8))
sns.boxplot(x='UniqueAnimalID', y='distance_per_day', data=df[df['UniqueAnimalID'].isin(sample_ids)] , palette='pastel')
plt.title('Distancia por día - Top 6 individuos')
plt.xlabel('ID Animal')
plt.ylabel('Distancia diaria (km)')
plt.show()

# %% [markdown]
# ---
#
# ### 6. **Variables ambientales**
#
# * Ver si `cdr_seaice_conc` tiene patrones por ubicación o fecha.
# * Confirmar por qué otras variables ambientales (`temp_surface`, etc.) están vacías.
# * Evaluar si deben recuperarse o descartarse.
#
# ---

# %%
# Relación entre velocidad y concentración de hielo
sns.scatterplot(data=df, x='cdr_seaice_conc', y='velocity_kmh')
# Out:
# <Axes: xlabel='cdr_seaice_conc', ylabel='velocity_kmh'>

# %% [markdown]
# ###  7. **Correlaciones e hipótesis iniciales**
#
# * Matriz de correlación entre variables físicas y ambientales.
# * Relación entre aceleración y cambios de dirección.
# * Relación entre velocidad y horas de luz o concentración de hielo.
#
# ---
#
# ###  8. **Preparación para visualización**
#
# * Muestras de trayectorias en mapas.
# * Análisis de comportamiento en función de condiciones ambientales.
# * Gráficos por individuo, día, región, estacionalidad.

# %%
# Simple con geopandas o folium
# O con scatterplot si no necesitas mapa base
sns.scatterplot(data=df, x='lon2', y='lat2', hue='UniqueAnimalID', s=10);
# Out:
# <Axes: xlabel='lon2', ylabel='lat2'>

# %%
# Subconjunto para no saturar el mapa (ajusta el número)
subset_ids = df['UniqueAnimalID'].unique()[:5]
df_subset = df[df['UniqueAnimalID'].isin(subset_ids)]

# Centro del mapa
center_lat = df_subset['lat2'].mean()
center_lon = df_subset['lon2'].mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=4, tiles='CartoDB positron')

# Crear un mapa de colores por ID
ids = list(df_subset['UniqueAnimalID'].unique())
colormap = cm.get_cmap('Set1', len(ids))
id_color_map = {uid: colors.rgb2hex(colormap(i)) for i, uid in enumerate(ids)}

# Añadir puntos codificados por color
for _, row in df_subset.iterrows():
    folium.CircleMarker(
        location=[row['lat2'], row['lon2']],
        radius=3,
        color=id_color_map[row['UniqueAnimalID']],
        fill=True,
        fill_opacity=0.7,
        popup=f"ID: {row['UniqueAnimalID']}, Fecha: {row['date_str']}"
    ).add_to(m)

# Mostrar mapa
m
# Out:
# C:\Users\Ana\AppData\Local\Temp\ipykernel_31572\4281879516.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colormap = cm.get_cmap('Set1', len(ids))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6fd3a5bbad2cfa547e033ef414d5f4b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6fd3a5bbad2cfa547e033ef414d5f4b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6fd3a5bbad2cfa547e033ef414d5f4b5 = L.map(
#                 &quot;map_6fd3a5bbad2cfa547e033ef414d5f4b5&quot;,
#                 {
#                     center: [116.68084594835263, -160.72994211932325],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5020f14bee95b169daa1439ba69d5bb = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e5020f14bee95b169daa1439ba69d5bb.addTo(map_6fd3a5bbad2cfa547e033ef414d5f4b5);
#
#
#             var circle_marker_f4076f2b9fb34f8a1df889af13999d95 = L.circleMarker(
#                 [68.83, -154.19],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e41a1c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e41a1c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6fd3a5bbad2cfa547e033ef414d5f4b5);
#
#
#         var popup_2a551faaf3dfe96c77b495a7ba63009f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95d4782c44e0fed922ab0ee74c12a891 = $(`&lt;div id=&quot;html_95d4782c44e0fed922ab0ee74c12a891&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 120, Fecha: 2008-08-30&lt;/div&gt;`)[0];
#                 popup_2a551faaf3dfe96c77b495a7ba63009f.setContent(html_95d4782c44e0fed922ab0ee74c12a891);
#
#
#
#         circle_marker_f4076f2b9fb34f8a1df889af13999d95.bindPopup(popup_2a551faaf3dfe96c77b495a7ba63009f)
#         ;
#
#
#
#
#             var circle_marker_7583c394e6cc50a14902b873e6067742 = L.circleMarker(
#                 [70.91, -148.22],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e41a1c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e41a1c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6fd3a5bbad2cfa547e033ef414d5f4b5);
#
#
#         var popup_9e91d59d34437bf96b831a7fbbbf1011 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03af51c0f7678fa6d72d3f5bb4817cc2 = $(`&lt;div id=&quot;html_03af51c0f7678fa6d72d3f5bb4817cc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 120, Fecha: 2008-08-30&lt;/div&gt;`)[0];
#                 popup_9e91d59d34437bf96b831a7fbbbf1011.setContent(html_03af51c0f7678fa6d72d3f5bb4817cc2);
#
#
#
#         circle_marker_7583c394e6cc50a14902b873e6067742.bindPopup(popup_9e91d59d34437bf96b831a7fbbbf1011)
#         ;
#
#
#
#
#             var circle_marker_37e70c5edb6c06f629acebd690f4678f = L.circleMarker(
#                 [73.03, -146.55],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e41a1c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e41a1c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6fd3a5bbad2cfa547e033ef414d5f4b5);
#
#
#         var popup_d6f37289ccc5320678595b4c1d0a2916 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab45d3c67b2ce1fad31918e5d14a05ef = $(`&lt;div id=&quot;html_ab45d3c67b2ce1fad31918e5d14a05ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 120, Fecha: 2008-08-30&lt;/div&gt;`)[0];
#                 popup_d6f37289ccc5320678595b4c1d0a2916.setContent(html_ab45d3c67b2ce1fad31918e5d14a05ef);
#
#
#
#         circle_marker_37e70c5edb6c06f629ace

# %%
import folium

m = folium.Map(location=[df_subset['adj_lat'].mean(), df_subset['adj_lon'].mean()], zoom_start=4)
for _, row in df_subset.iterrows():
    folium.Marker(
        location=(row['adj_lat'], row['adj_lon']),
        popup=f"ID: {row['UniqueAnimalID']}<br>Fecha: {row['date_str']}"
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3001270ec102183ef26fa0644a7d096 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3001270ec102183ef26fa0644a7d096&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e3001270ec102183ef26fa0644a7d096 = L.map(
#                 &quot;map_e3001270ec102183ef26fa0644a7d096&quot;,
#                 {
#                     center: [116.68094542660012, -160.72996045114178],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c4b1d192799e9fcee098036043a8e8b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9c4b1d192799e9fcee098036043a8e8b.addTo(map_e3001270ec102183ef26fa0644a7d096);
#
#
#             var marker_767216b96a8a549178e4f9ec49f1d948 = L.marker(
#                 [68.8272528125133, -154.18647346840007],
#                 {
# }
#             ).addTo(map_e3001270ec102183ef26fa0644a7d096);
#
#
#         var popup_f3c8cacca5007cf8a1d8a22f57e74c84 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_353865882daa406026c3b6ee0d37f943 = $(`&lt;div id=&quot;html_353865882daa406026c3b6ee0d37f943&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 120&lt;br&gt;Fecha: 2008-08-30&lt;/div&gt;`)[0];
#                 popup_f3c8cacca5007cf8a1d8a22f57e74c84.setContent(html_353865882daa406026c3b6ee0d37f943);
#
#
#
#         marker_767216b96a8a549178e4f9ec49f1d948.bindPopup(popup_f3c8cacca5007cf8a1d8a22f57e74c84)
#         ;
#
#
#
#
#             var marker_ff5590d67f86d5bfabda532890b75e84 = L.marker(
#                 [70.90706891919554, -148.22349613168666],
#                 {
# }
#             ).addTo(map_e3001270ec102183ef26fa0644a7d096);
#
#
#         var popup_24530de3825861db88603e0d91a4d1d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_382e915893bdf72d0a4fa585fa29cc4d = $(`&lt;div id=&quot;html_382e915893bdf72d0a4fa585fa29cc4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 120&lt;br&gt;Fecha: 2008-08-30&lt;/div&gt;`)[0];
#                 popup_24530de3825861db88603e0d91a4d1d1.setContent(html_382e915893bdf72d0a4fa585fa29cc4d);
#
#
#
#         marker_ff5590d67f86d5bfabda532890b75e84.bindPopup(popup_24530de3825861db88603e0d91a4d1d1)
#         ;
#
#
#
#
#             var marker_3bb43497811c199c95ecb25200e6de15 = L.marker(
#                 [73.0276310231723, -146.5461427359317],
#                 {
# }
#             ).addTo(map_e3001270ec102183ef26fa0644a7d096);
#
#
#         var popup_a99f6d8a319d407901a3abf8b9cf5a56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f032f4446cf0c625024b2391f5ccf639 = $(`&lt;div id=&quot;html_f032f4446cf0c625024b2391f5ccf639&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 120&lt;br&gt;Fecha: 2008-08-30&lt;/div&gt;`)[0];
#                 popup_a99f6d8a319d407901a3abf8b9cf5a56.setContent(html_f032f4446cf0c625024b2391f5ccf639);
#
#
#
#         marker_3bb43497811c199c95ecb25200e6de15.bindPopup(popup_a99f6d8a319d407901a3abf8b9cf5a56)
#         ;
#
#
#
#
#             var marker_0be0dd79a130d3e972ef5e580d3c9fc9 = L.marker(
#                 [71.74150561187668, -159.60033255485894],
#                 {
# }
#             ).addTo(map_e3001270ec102183ef26fa0644a7d096);
#
#
#         var popup_7840aaba9ebdb5b59682c56652198fc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_341c1208704d9d67b24a8560754edbf0 = $(`&lt;div id=&quot;html_341c1208704d9d67b24a8560754edbf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 120&lt;br&gt;Fecha: 2008-08-31&lt;/div&gt;`)[0];
#                 popup_7840aaba9ebdb5b59682c56652198fc5.setContent(html_341c1208704d9d67b24a8560754edbf0);
#
#
#
#         marker_0be0dd79a130d3e972ef5e580d3c9fc9.bindPopup(popup_7840aaba9ebdb5b59682c56652198fc5)
#         ;
#
#
#
#
#             var marker_02ec2bc9b834e0e8eddd413457e14686 = L.marker(
#                 [71.98356702751235, -152.2080994153235],
#                 {
# }
#             ).addTo(map_e3001270ec102183ef26fa0644a7d096);
#
#
#         var popup_f0f8cbf925d7dd3547963f75d516877f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09d5581dbeac308ae2d944127e12a1ab = $(`&lt;div id=&quot;html_09d5581dbeac308ae2d944127e12a1ab&quot; style=&quot;width: 100.0%; height: 100.0%

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Seleccionar un oso
bear = df[df['UniqueAnimalID'] == 418]

# Crear figura con proyección polar estereográfica norte
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection=ccrs.NorthPolarStereo())

# Agregar elementos geográficos
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.gridlines()
ax.set_extent([-180, 180, 60, 90], crs=ccrs.PlateCarree())

# Plotear la trayectoria
ax.plot(
    bear['mu_lon'], bear['mu_lat'],
    transform=ccrs.PlateCarree(),
    marker='o', markersize=2, linewidth=1,
    label='Trayectoria Oso 418'
)

plt.title('Trayectoria del oso polar (ID 418)')
plt.legend()
plt.show();

# %%
print(df[['adj_lat', 'adj_lon']].describe())
# Out:
#              adj_lat        adj_lon
# count  122014.000000  122014.000000
# mean       74.111507    -100.241691
# std      1297.923625    1310.889545
# min    -17851.466044  -17984.632851
# 25%      -140.192963    -327.366128
# 50%        72.614608    -145.692597
# 75%       290.086473     179.903156
# max     18979.301685   19181.051648

# %%
# 2. Filtrar por latitudes > 60° N (zona ártica)
df_arctic = df[df['adj_lat'] > 60]
len(df_arctic)
# Out:
# 79108

# %%
# 3. Ver puntos fuera de rango
df_outliers = df[df['adj_lat'] < 40]
len(df_outliers)
# Out:
# 41029

# %% [markdown]
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122014 entries, 0 to 122013
# Data columns (total 32 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   UniqueAnimalID     122014 non-null  int64
#  1   timestamp          122014 non-null  object
#  2   mu_lat             122014 non-null  float64
#  3   mu_lon             122014 non-null  float64
#  4   se_mu_x            122014 non-null  int64
#  5   se_mu_y            122014 non-null  int64
#  6   adj_lat            122014 non-null  float64
#  7   adj_lon            122014 non-null  float64
#  8   date_str           122014 non-null  object
#  9   lat2               122014 non-null  float64
#  10  lon2               122014 non-null  float64
#  11  proj_x             122014 non-null  float64
#  12  proj_y             122014 non-null  float64
#  13  distance_km        122014 non-null  float64
#  14  velocity_kmh       122014 non-null  float64
#  15  acceleration_kmh2  122014 non-null  float64
#  16  daylight_hours     122014 non-null  float64
#  17  is_polar_night     122014 non-null  bool
#  18  is_midnight_sun    122014 non-null  bool
#  19  cdr_seaice_conc    31664 non-null   float64
#  20  temp_surface       0 non-null       float64
#  21  wind_speed         0 non-null       float64
#  22  cloud_cover        0 non-null       float64
#  23  prev_lat           121841 non-null  float64
#  24  prev_lon           121841 non-null  float64
#  25  prev_se_x          121841 non-null  float64
#  26  prev_se_y          121841 non-null  float64
#  27  bearing            121841 non-null  float64
#  28  prev_bearing       121668 non-null  float64
#  29  bearing_change     122014 non-null  float64
#  30  date               122014 non-null  object
#  31  distance_per_day   122014 non-null  float64
# dtypes: bool(2), float64(24), int64(3), object(3)
# memory usage: 28.2+ MB

# %%
df.describe()
# Out:
#        UniqueAnimalID                      timestamp         mu_lat  \
# count   338413.000000                         338413  338413.000000
# mean       261.228664  2001-06-08 11:02:24.834861568      72.380540
# min          1.000000            1985-07-01 00:00:00      63.383000
# 25%        124.000000            1992-07-26 18:00:00      70.892100
# 50%        280.000000            2002-09-30 06:00:00      71.913600
# 75%        375.000000            2009-08-24 18:00:00      73.505800
# max        541.000000            2017-11-30 18:00:00      83.901400
# std        151.938359                            NaN       2.190199
#
#               mu_lon        se_mu_x        se_mu_y           hour  \
# count  338413.000000  338413.000000  338413.000000  338413.000000
# mean     -114.949210   10146.473454   10146.473454       8.999034
# min      -179.999900      11.000000      11.000000       0.000000
# 25%      -163.503400    2697.000000    2697.000000       0.000000
# 50%      -149.778200    8513.000000    8513.000000       6.000000
# 75%      -140.424300   15010.000000   15010.000000      12.000000
# max       179.999800   66766.000000   66766.000000      18.000000
# std       107.879343    8804.758996    8804.758996       6.708206
#
#                 date       prev_lat       prev_lon    distance_km
# count  338413.000000  338007.000000  338007.000000  338413.000000
# mean      255.790304      72.381866    -114.951745       4.244658
# min       182.000000      63.383000    -179.999900       0.000000
# 25%       218.000000      70.892800    -163.491500       1.541732
# 50%       255.000000      71.914800    -149.773800       3.172079
# 75%       292.000000      73.506900    -140.423700       5.445784
# max       335.000000      83.901400     179.999800    1414.363381
# std        43.273149       2.189634     107.869823      10.735746

# %% [markdown]
# - ¿pairplot? distribucion
# - heatmap ... corr
# - outliers?
